# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re

# %%
url = "https://fbref.com/en/comps/13/3243/2019-2020-Ligue-1-Stats"

# %%
standard_stats = ["player", "nationality","position","age","games","games_starts","minutes","minutes_90s","goals","assists","goals_pens","pens_made","pens_att","cards_yellow","cards_red","goals_per_90","assists_per90","goals_assists_per90","goals_assists_pens_per90","xg","npxg","xa","npxg_xa","xg_per90","xa_per90","xg_xa_per90","npxg_per90","npxg_xa_per90"]

# %%
res = requests.get(url)

# %%
#to get over the scrap breaker
comm = re.compile("<!--|-->")
soup = BeautifulSoup(comm.sub("",res.text),'html.parser')

# %%
tables = soup.find_all("tbody")

# %%
def get_links(table):
    team_links = []
    teams = table.find_all("tr")
    for row in teams:
        squad = row.find_all("td",{'data-stat':'squad'})
        link = squad[0].find("a", href = True)
        team_links.append(link['href'])
    return team_links

# %%
df = []
df = get_links(tables[0])

# %%
df
# Out:
# ['/en/squads/e2d8892c/2019-2020/Paris-Saint-Germain-Stats',
#  '/en/squads/5725cc7b/2019-2020/Marseille-Stats',
#  '/en/squads/b3072e00/2019-2020/Rennes-Stats',
#  '/en/squads/cb188c0c/2019-2020/Lille-Stats',
#  '/en/squads/132ebc33/2019-2020/Nice-Stats',
#  '/en/squads/7fdd64e0/2019-2020/Reims-Stats',
#  '/en/squads/d53c0b06/2019-2020/Lyon-Stats',
#  '/en/squads/281b0e73/2019-2020/Montpellier-Stats',
#  '/en/squads/fd6114db/2019-2020/Monaco-Stats',
#  '/en/squads/c0d3eab4/2019-2020/Strasbourg-Stats',
#  '/en/squads/69236f98/2019-2020/Angers-Stats',
#  '/en/squads/123f3efe/2019-2020/Bordeaux-Stats',
#  '/en/squads/d7a486cd/2019-2020/Nantes-Stats',
#  '/en/squads/fb08dbb3/2019-2020/Brest-Stats',
#  '/en/squads/f83960ae/2019-2020/Metz-Stats',
#  '/en/squads/8dfb7350/2019-2020/Dijon-Stats',
#  '/en/squads/d298ef2c/2019-2020/Saint-Etienne-Stats',
#  '/en/squads/1cbf5f9e/2019-2020/Nimes-Stats',
#  '/en/squads/25622401/2019-2020/Amiens-Stats',
#  '/en/squads/3f8c4b5f/2019-2020/Toulouse-Stats']

# %%
def modify_links(df_link):
    final_links = []
    for link in df_link:
        split = link.split("/")
        split[5] = split[5] + "-All-Competitions"
        split.append(split[5])
        split[5] = "all-comps"
        separator = "/"
        final_links.append("https://fbref.com"+separator.join(split))
    return final_links

# %%
df_again = modify_links(df)

# %% [markdown]
# # Scrapping Main

# %%
req = requests.get(df_again[0])

# %%
#to get over the scrap breaker
comm = re.compile("<!--|-->")
soup = BeautifulSoup(comm.sub("",req.text),'html.parser')

# %%
tables = soup.find_all("tbody")

# %%
len(tables)
# Out:
# 13

# %%
players= tables[0].find_all("tr")

# %%
pre_df_player = dict()
for row in players:
        if(row.find('th',{"scope":"row"}) != None):
            
            for f in standard_stats:                
                cell = row.find("td",{"data_stat":f})
                a = cell.text.strip().encode()
                text=a.decode("utf-8")
                if(text == ''):
                    text = '0'
                if((f!='player')&(f!='nationality')&(f!='position')&(f!='squad')&(f!='age')&(f!='birth_year')):
                    text = float(text.replace(',',''))
                if f in pre_df_player:
                    pre_df_player[f].append(text)
                else:
                    pre_df_player[f] = [text]
df_player = pd.DataFrame.from_dict(pre_df_player)

# %%
df_player
# Out:
#     player nationality position     age   games games_starts minutes  \
# 0   ar ARG      ar ARG   ar ARG  ar ARG  ar ARG       ar ARG  ar ARG
# 1   cr CRC      cr CRC   cr CRC  cr CRC  cr CRC       cr CRC  cr CRC
# 2   br BRA      br BRA   br BRA  br BRA  br BRA       br BRA  br BRA
# 3   sn SEN      sn SEN   sn SEN  sn SEN  sn SEN       sn SEN  sn SEN
# 4   fr FRA      fr FRA   fr FRA  fr FRA  fr FRA       fr FRA  fr FRA
# 5   es ESP      es ESP   es ESP  es ESP  es ESP       es ESP  es ESP
# 6   it ITA      it ITA   it ITA  it ITA  it ITA       it ITA  it ITA
# 7   br BRA      br BRA   br BRA  br BRA  br BRA       br BRA  br BRA
# 8   br BRA      br BRA   br BRA  br BRA  br BRA       br BRA  br BRA
# 9   ar ARG      ar ARG   ar ARG  ar ARG  ar ARG       ar ARG  ar ARG
# 10  be BEL      be BEL   be BEL  be BEL  be BEL       be BEL  be BEL
# 11  fr FRA      fr FRA   fr FRA  fr FRA  fr FRA       fr FRA  fr FRA
# 12  sn SEN      sn SEN   sn SEN  sn SEN  sn SEN       sn SEN  sn SEN
# 13  es ESP      es ESP   es ESP  es ESP  es ESP       es ESP  es ESP
# 14  fr FRA      fr FRA   fr FRA  fr FRA  fr FRA       fr FRA  fr FRA
# 15  ar ARG      ar ARG   ar ARG  ar ARG  ar ARG       ar ARG  ar ARG
# 16  de GER      de GER   de GER  de GER  de GER       de GER  de GER
# 17  fr FRA      fr FRA   fr FRA  fr FRA  fr FRA       fr FRA  fr FRA
# 18  uy URU      uy URU   uy URU  uy URU  uy URU       uy URU  uy URU
# 19  es ESP      es ESP   es ESP  es ESP  es ESP       es ESP  es ESP
# 20  de GER      de GER   de GER  de GER  de GER       de GER  de GER
# 21  cm CMR      cm CMR   cm CMR  cm CMR  cm CMR       cm CMR  cm CMR
# 22  fr FRA      fr FRA   fr FRA  fr FRA  fr FRA       fr FRA  fr FRA
# 23  fr FRA      fr FRA   fr FRA  fr FRA  fr FRA       fr FRA  fr FRA
# 24  es ESP      es ESP   es ESP  es ESP  es ESP       es ESP  es ESP
# 25  nl NED      nl NED   nl NED  nl NED  nl NED       nl NED  nl NED
# 26  pl POL      pl POL   pl POL  pl POL  pl POL       pl POL  pl POL
# 27  fr FRA      fr FRA   fr FRA  fr FRA  fr FRA       fr FRA  fr FRA
# 28  fr FRA      fr FRA   fr FRA  fr FRA  fr FRA       fr FRA  fr FRA
# 29  fr FRA      fr FRA   fr FRA  fr FRA  fr FRA       fr FRA  fr FRA
# 30  es ESP      es ESP   es ESP  es ESP  es ESP       es ESP  es ESP
# 31  ht HAI      ht HAI   ht HAI  ht HAI  ht HAI       ht HAI  ht HAI
# 32  fr FRA      fr FRA   fr FRA  fr FRA  fr FRA       fr FRA  fr FRA
#
#    minutes_90s   goals assists  ... goals_assists_pens_per90      xg    npxg  \
# 0       ar ARG  ar ARG  ar ARG  ...                   ar ARG  ar ARG  ar ARG
# 1       cr CRC  cr CRC  cr CRC  ...                   cr CRC  cr CRC  cr CRC
# 2       br BRA  br BRA  br BRA  ...                   br BRA  br BRA  br BRA
# 3       sn SEN  sn SEN  sn SEN  ...                   sn SEN  sn SEN  sn SEN
# 4       fr FRA  fr FRA  fr FRA  ...                   fr FRA  fr FRA  fr FRA
# 5       es ESP  es ESP  es ESP  ...                   es ESP  es ESP  es ESP
# 6       it ITA  it ITA  it ITA  ...                   it ITA  it ITA  it ITA
# 7       br BRA  br BRA  br BRA  ...                   br BRA  br BRA  br BRA
# 8       br BRA  br BRA  br BRA  ...                   br BRA  br BRA  br BRA
# 9       ar ARG  ar ARG  ar ARG  ...                   ar ARG  ar ARG  ar ARG
# 10      be BEL  be BEL  be BEL  ...                   be BEL  be BEL  be BEL
# 11      fr FRA  fr FRA  fr FRA  ...                   fr FRA  fr FRA  fr FRA
# 12      sn SEN  sn SEN  sn SEN  ...                   sn SEN  sn SEN  sn SEN
# 13      es ESP  es ESP  es ESP  ...                   es ESP  es ESP  es ESP
# 14      fr FRA  fr FRA  fr FRA  ...                   fr FRA  fr FRA  fr FRA
# 15      ar ARG  ar ARG  ar ARG  ...                   ar ARG  ar ARG  ar ARG
# 16      de GER  de GER  de GER  ...                   de GER  de GER  de GER
# 17      fr FRA  fr FRA  fr FRA  ...                   fr FRA  fr FRA  fr FRA
# 18      uy URU  uy URU  uy URU  ...                   uy URU  uy URU  uy URU
# 19      es ESP  es ESP  es ESP  ...                   es ESP  es ESP  es ESP
# 20      de GER  de GER  de GER  ...                   de GER  de GER  de GER
# 21      cm CMR  cm CMR  cm CMR  ...                   cm CMR  cm CMR  cm CMR
# 22      fr FRA  fr FRA  fr FRA  ...                   fr FRA  fr FRA  fr FRA
# 23      fr FRA  fr FRA  fr FRA  ...                   fr FRA  fr FRA  fr FRA
# 24      es ESP  es ESP  es ESP  ...                   es ESP  es ESP  es ESP
# 25      nl NED  nl NED  nl NED  ...                   nl NED  nl NED  nl NED
# 26      pl POL  pl POL  pl POL  ...                   pl POL  pl POL  pl POL
# 27      fr FRA  fr FRA  fr FRA  ...                   fr FRA  fr FRA  fr FRA
# 28      fr FRA  fr FRA  fr FRA  ...                   fr FRA  fr FRA  fr FRA
# 29      fr FRA  fr FRA  fr FRA  ...                   fr FRA  fr FRA  fr FRA
# 30      es ESP  es ESP  es ESP  ...                   es ESP  es ESP  es ESP
# 31      ht HAI  ht HAI  ht HAI  ...                   ht HAI  ht HAI  ht HAI
# 32      fr FRA  fr FRA  fr FRA  ...                   fr FRA  fr FRA  fr FRA
#
#         xa npxg_xa xg_per90 xa_per90 xg_xa_per90 npxg_per90 npxg_xa_per90
# 0   ar ARG  ar ARG   ar ARG   ar ARG      ar ARG     ar ARG        ar ARG
# 1   cr CRC  cr CRC   cr CRC   cr CRC      cr CRC     cr CRC        cr CRC
# 2   br BRA  br BRA   br BRA   br BRA      br BRA     br BRA        br BRA
# 3   sn SEN  sn SEN   sn SEN   sn SEN      sn SEN     sn SEN        sn SEN
# 4   fr FRA  fr FRA   fr FRA   fr FRA      fr FRA     fr FRA        fr FRA
# 5   es ESP  es ESP   es ESP   es ESP      es ESP     es ESP        es ESP
# 6   it ITA  it ITA   it ITA   it ITA      it ITA     it ITA        it ITA
# 7   br BRA  br BRA   br BRA   br BRA      br BRA     br BRA        br BRA
# 8   br BRA  br BRA   br BRA   br BRA      br BRA     br BRA        br BRA
# 9   ar ARG  ar ARG   ar ARG   ar ARG      ar ARG     ar ARG        ar ARG
# 10  be BEL  be BEL   be BEL   be BEL      be BEL     be BEL        be BEL
# 11  fr FRA  fr FRA   fr FRA   fr FRA      fr FRA     fr FRA        fr FRA
# 12  sn SEN  sn SEN   sn SEN   sn SEN      sn SEN     sn SEN        sn SEN
# 13  es ESP  es ESP   es ESP   es ESP      es ESP     es ESP        es ESP
# 14  fr FRA  fr FRA   fr FRA   fr FRA      fr FRA     fr FRA        fr FRA
# 15  ar ARG  ar ARG   ar ARG   ar ARG      ar ARG     ar ARG        ar ARG
# 16  de GER  de GER   de GER   de GER      de GER     de GER        de GER
# 17  fr FRA  fr FRA   fr FRA   fr FRA      fr FRA     fr FRA        fr FRA
# 18  uy URU  uy URU   uy URU   uy URU      uy URU     uy URU        uy URU
# 19  es ESP  es ESP   es ESP   es ESP      es ESP     es ESP        es ESP
# 20  de GER  de GER   de GER   de GER      de GER     de GER        de GER
# 21  cm CMR  cm CMR   cm CMR   cm CMR      cm CMR     cm CMR        cm CMR
# 22  fr FRA  fr FRA   fr FRA   fr FRA      fr FRA     fr FRA        fr FRA
# 23  fr FRA  fr FRA   fr FRA   fr FRA      fr FRA     fr FRA        fr FRA
# 24  es ESP  es ESP   es ESP   es ESP      es ESP     es ESP        es ESP
# 25  nl NED  nl NED   nl NED   nl NED      nl NED     nl NED        nl NED
# 26  pl POL  pl POL   pl POL   pl POL      pl POL     pl POL        pl POL
# 27  fr FRA  fr FRA   fr FRA   fr FRA      fr FRA     fr FRA        fr FRA
# 28  fr FRA  fr FRA   fr FRA   fr FRA      fr FRA     fr FRA        fr FRA
# 29  fr FRA  fr FRA   fr FRA   fr FRA      fr FRA     fr FRA        fr FRA
# 30  es ESP  es ESP   es ESP   es ESP      es ESP     es ESP        es ESP
# 31  ht HAI  ht HAI   ht HAI   ht HAI      ht HAI     ht HAI        ht HAI
# 32  fr FRA  fr FRA   fr FRA   fr FRA      fr FRA     fr FRA        fr FRA
#
# [33 rows x 28 columns]
